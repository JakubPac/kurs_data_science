# %% [markdown]
# <a href="https://colab.research.google.com/github/JakubPac/kurs_data_science/blob/main/regresja_liniowa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import sklearn

# %%
x = np.arange(0, 50, 0.5)
noise = 10 * np.random.randn(100)
y = 2 * x + 100 + noise
X = x.reshape(-1,1)

print(X.shape)
print(y.shape)
# Out:
# (100, 1)
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (75, 1)
# (25, 1)
# (75,)
# (25,)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.figure(figsize = (7, 5))
plt.scatter(X_train, y_train, c ='b', label='Zbior treningowy')
plt.scatter(X_test, y_test, c ='g', label='Zbior testowy')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

print(model.coef_)
print(model.intercept_)
# Out:
# [2.02245611]
# 100.91307360346568

# %%
plt.figure(figsize = (7, 5))
plt.scatter(X_train, y_train, c ='b', label='Zbior treningowy')
plt.plot(X,model.intercept_ + model.coef_[0] * X, c = 'red')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %%
y_pred = model.predict(X_test)
plt.figure(figsize = (7, 5))
plt.scatter(X_test, y_test, c ='g', label='Zbior testowy')
plt.plot(X,model.intercept_ + model.coef_[0] * X, c = 'red')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# ocena modelu

# %%
model.score(X_test, y_test)
# Out:
# 0.8848241136155929
