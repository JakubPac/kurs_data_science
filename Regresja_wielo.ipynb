# %% [markdown]
# <a href="https://colab.research.google.com/github/JakubPac/kurs_data_science/blob/main/Regresja_wielo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
np.random.seed(0)

# %%
X = np.arange(-10, 10, 0.5)
noise = 80 * np.random.randn(40)
y = - X ** 3 + 10 * X ** 2 - 2*X + 3 + noise
X = X.reshape(-1,1)
_ = plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X,y)
y_pred = regressor.predict(X)

plt.scatter(X,y)
_ = plt.plot(X, y_pred, c = 'red')

# %%
from sklearn.metrics import r2_score
r2_score(y, y_pred)
# Out:
# 0.5398062344255777

# %% [markdown]
# Zwiekszenie zlozonosci modelu

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2)
X_poly = poly.fit_transform(X)
X_poly
# Out:
# array([[  1.  , -10.  , 100.  ],
#        [  1.  ,  -9.5 ,  90.25],
#        [  1.  ,  -9.  ,  81.  ],
#        [  1.  ,  -8.5 ,  72.25],
#        [  1.  ,  -8.  ,  64.  ],
#        [  1.  ,  -7.5 ,  56.25],
#        [  1.  ,  -7.  ,  49.  ],
#        [  1.  ,  -6.5 ,  42.25],
#        [  1.  ,  -6.  ,  36.  ],
#        [  1.  ,  -5.5 ,  30.25],
#        [  1.  ,  -5.  ,  25.  ],
#        [  1.  ,  -4.5 ,  20.25],
#        [  1.  ,  -4.  ,  16.  ],
#        [  1.  ,  -3.5 ,  12.25],
#        [  1.  ,  -3.  ,   9.  ],
#        [  1.  ,  -2.5 ,   6.25],
#        [  1.  ,  -2.  ,   4.  ],
#        [  1.  ,  -1.5 ,   2.25],
#        [  1.  ,  -1.  ,   1.  ],
#        [  1.  ,  -0.5 ,   0.25],
#        [  1.  ,   0.  ,   0.  ],
#        [  1.  ,   0.5 ,   0.25],
#        [  1.  ,   1.  ,   1.  ],
#        [  1.  ,   1.5 ,   2.25],
#        [  1.  ,   2.  ,   4.  ],
#        [  1.  ,   2.5 ,   6.25],
#        [  1.  ,   3.  ,   9.  ],
#        [  1.  ,   3.5 ,  12.25],
# ...

# %%
regressor_poly = LinearRegression()
regressor_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
y_pred = regressor_poly.predict(X_poly)

plt.scatter(X,y)
_ = plt.plot(X, y_pred, c = 'red')

# %%
r2_score(y, y_pred)
# Out:
# 0.9000601519884677

# %%
poly = PolynomialFeatures(degree = 3)
X_poly = poly.fit_transform(X)
X_poly
# Out:
# array([[ 1.00000e+00, -1.00000e+01,  1.00000e+02, -1.00000e+03],
#        [ 1.00000e+00, -9.50000e+00,  9.02500e+01, -8.57375e+02],
#        [ 1.00000e+00, -9.00000e+00,  8.10000e+01, -7.29000e+02],
#        [ 1.00000e+00, -8.50000e+00,  7.22500e+01, -6.14125e+02],
#        [ 1.00000e+00, -8.00000e+00,  6.40000e+01, -5.12000e+02],
#        [ 1.00000e+00, -7.50000e+00,  5.62500e+01, -4.21875e+02],
#        [ 1.00000e+00, -7.00000e+00,  4.90000e+01, -3.43000e+02],
#        [ 1.00000e+00, -6.50000e+00,  4.22500e+01, -2.74625e+02],
#        [ 1.00000e+00, -6.00000e+00,  3.60000e+01, -2.16000e+02],
#        [ 1.00000e+00, -5.50000e+00,  3.02500e+01, -1.66375e+02],
#        [ 1.00000e+00, -5.00000e+00,  2.50000e+01, -1.25000e+02],
#        [ 1.00000e+00, -4.50000e+00,  2.02500e+01, -9.11250e+01],
#        [ 1.00000e+00, -4.00000e+00,  1.60000e+01, -6.40000e+01],
#        [ 1.00000e+00, -3.50000e+00,  1.22500e+01, -4.28750e+01],
# ...

# %%
regressor_poly3 = LinearRegression()
regressor_poly3.fit(X_poly, y)
y_pred =regressor_poly3.predict(X_poly)

plt.scatter(X,y)
_ = plt.plot(X, y_pred, c = 'red')

# %%
r2_score(y, y_pred)
# Out:
# 0.9793138557357745
