# %% [markdown]
# <a href="https://colab.research.google.com/github/JakubPac/kurs_data_science/blob/main/%C5%82aczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
def fetch_financial_data(company = 'META'):
  import pandas_datareader.data as web
  return web.DataReader(name = company, data_source = 'stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1255 entries, 2025-08-08 to 2020-08-11
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1255 non-null   float64
#  1   High    1255 non-null   float64
#  2   Low     1255 non-null   float64
#  3   Close   1255 non-null   float64
#  4   Volume  1255 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.8 KB

# %%
apple.head()
# Out:
#                Open    High      Low   Close     Volume
# Date
# 2025-08-08  220.830  231.00  219.250  229.35  113853967
# 2025-08-07  218.875  220.85  216.580  220.03   90224834
# 2025-08-06  205.630  215.38  205.590  213.25  108483103
# 2025-08-05  203.400  205.34  202.160  202.92   44155079
# 2025-08-04  204.505  207.88  201.675  203.35   75109298

# %% [markdown]
# Preprocessing

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2025-08-08     220.830      231.00    219.250       229.35     113853967
# 2025-08-07     218.875      220.85    216.580       220.03      90224834
# 2025-08-06     205.630      215.38    205.590       213.25     108483103
# 2025-08-05     203.400      205.34    202.160       202.92      44155079
# 2025-08-04     204.505      207.88    201.675       203.35      75109298

# %% [markdown]
# konkatenacja danych

# %%
df = pd.concat(objs = [apple, amazon, google, uber], axis = 1)

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

df.describe().T
# Out:
#                 count        mean         std         min         25%  \
# apple_open    1255.00      168.70       36.11      101.93      140.89
# apple_high    1255.00      170.59       36.37      107.45      142.71
# apple_low     1255.00      166.95       35.94      100.54      139.41
# apple_close   1255.00      168.85       36.21      104.19      141.10
# apple_volume  1255.00 78245396.29 39109117.02 23260251.00 51430087.00
# amazon_open   1255.00      157.99       35.49       82.80      132.06
# amazon_high   1255.00      159.89       35.61       83.48      133.63
# amazon_low    1255.00      155.95       35.30       81.43      130.46
# amazon_close  1255.00      157.95       35.48       81.82      132.03
# amazon_volume 1255.00 61488897.07 29043203.08 15007497.00 41976993.00
# google_open   1255.00      131.45       31.43       69.88      105.22
# google_high   1255.00      132.98       31.67       71.64      106.81
# google_low    1255.00      130.02       31.14       69.85      104.11
# google_close  1255.00      131.52       31.41       70.21      105.49
# google_volume 1255.00 32296151.42 13697975.45  9346519.00 23386344.50
# uber_open     1255.00       50.97       18.80       20.37       34.63
# uber_high     1255.00       51.86       18.96       21.13       35.25
# uber_low      1255.00       50.06       18.57       19.89       33.97
# uber_close    1255.00       50.97       18.77       20.46       34.58
# uber_volume   1255.00 23807110.41 16279225.59  5200356.00 15630179.00
#
#                       50%         75%          max
# apple_open         167.00      192.46       257.91
# apple_high         168.41      194.05       259.81
# apple_low          165.28      190.86       257.35
# apple_close        166.82      192.37       258.74
# apple_volume  69135904.00 92925751.50 354772009.00
# amazon_open        161.13      179.96       239.01
# amazon_high        163.02      182.12       242.52
# amazon_low         159.25      177.37       238.03
# amazon_close       161.25      179.57       242.06
# amazon_volume 54969133.00 72866270.50 272661720.00
# google_open        131.48      154.89       203.39
# google_high        133.04      156.79       207.05
# google_low         130.19      152.85       202.81
# google_close       132.04      154.77       206.38
# google_volume 28933367.00 36984944.00 127747554.00
# uber_open           47.05       67.16        97.50
# uber_high           47.73       68.58        97.72
# uber_low            46.35       66.03        96.10
# uber_close          47.07       67.16        97.48
# uber_volume   20152597.00 27700052.00 364261230.00

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.53
# apple_high           1.00        1.00       1.00         1.00         -0.52
# apple_low            1.00        1.00       1.00         1.00         -0.55
# apple_close          1.00        1.00       1.00         1.00         -0.53
# apple_volume        -0.53       -0.52      -0.55        -0.53          1.00
# amazon_open          0.56        0.56       0.56         0.56         -0.13
# amazon_high          0.56        0.56       0.56         0.56         -0.12
# amazon_low           0.56        0.56       0.56         0.56         -0.14
# amazon_close         0.56        0.56       0.56         0.56         -0.13
# amazon_volume       -0.51       -0.50      -0.52        -0.51          0.60
# google_open          0.87        0.87       0.87         0.87         -0.48
# google_high          0.87        0.87       0.87         0.87         -0.47
# google_low           0.87        0.87       0.87         0.87         -0.48
# google_close         0.87        0.87       0.87         0.87         -0.48
# google_volume       -0.10       -0.10      -0.11        -0.11          0.29
# uber_open            0.66        0.66       0.66         0.66         -0.35
# uber_high            0.66        0.66       0.66         0.66         -0.35
# uber_low             0.66        0.66       0.66         0.66         -0.36
# uber_close           0.66        0.66       0.66         0.66         -0.35
# uber_volume         -0.04       -0.04      -0.05        -0.05          0.14
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.56         0.56        0.56          0.56
# apple_high            0.56         0.56        0.56          0.56
# apple_low             0.56         0.56        0.56          0.56
# apple_close           0.56         0.56        0.56          0.56
# apple_volume         -0.13        -0.12       -0.14         -0.13
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.33        -0.32       -0.35         -0.34
# google_open           0.76         0.76        0.76          0.76
# google_high           0.75         0.76        0.75          0.76
# google_low            0.76         0.76        0.76          0.76
# google_close          0.76         0.76        0.76          0.76
# google_volume        -0.09        -0.08       -0.10         -0.09
# uber_open             0.80         0.80        0.81          0.81
# uber_high             0.81         0.80        0.81          0.81
# uber_low              0.80         0.80        0.81          0.80
# uber_close            0.80         0.80        0.81          0.80
# uber_volume          -0.09        -0.09       -0.10         -0.09
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.51         0.87         0.87        0.87
# apple_high             -0.50         0.87         0.87        0.87
# apple_low              -0.52         0.87         0.87        0.87
# apple_close            -0.51         0.87         0.87        0.87
# apple_volume            0.60        -0.48        -0.47       -0.48
# amazon_open            -0.33         0.76         0.75        0.76
# amazon_high            -0.32         0.76         0.76        0.76
# amazon_low             -0.35         0.76         0.75        0.76
# amazon_close           -0.34         0.76         0.76        0.76
# amazon_volume           1.00        -0.50        -0.49       -0.51
# google_open            -0.50         1.00         1.00        1.00
# google_high            -0.49         1.00         1.00        1.00
# google_low             -0.51         1.00         1.00        1.00
# google_close           -0.50         1.00         1.00        1.00
# google_volume           0.44        -0.12        -0.11       -0.14
# uber_open              -0.46         0.74         0.74        0.74
# uber_high              -0.46         0.74         0.74        0.74
# uber_low               -0.47         0.74         0.74        0.74
# uber_close             -0.46         0.74         0.74        0.74
# uber_volume             0.23        -0.05        -0.05       -0.06
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.87          -0.10       0.66       0.66      0.66
# apple_high             0.87          -0.10       0.66       0.66      0.66
# apple_low              0.87          -0.11       0.66       0.66      0.66
# apple_close            0.87          -0.11       0.66       0.66      0.66
# apple_volume          -0.48           0.29      -0.35      -0.35     -0.36
# amazon_open            0.76          -0.09       0.80       0.81      0.80
# amazon_high            0.76          -0.08       0.80       0.80      0.80
# amazon_low             0.76          -0.10       0.81       0.81      0.81
# amazon_close           0.76          -0.09       0.81       0.81      0.80
# amazon_volume         -0.50           0.44      -0.46      -0.46     -0.47
# google_open            1.00          -0.12       0.74       0.74      0.74
# google_high            1.00          -0.11       0.74       0.74      0.74
# google_low             1.00          -0.14       0.74       0.74      0.74
# google_close           1.00          -0.13       0.74       0.74      0.74
# google_volume         -0.13           1.00      -0.07      -0.07     -0.08
# uber_open              0.74          -0.07       1.00       1.00      1.00
# uber_high              0.74          -0.07       1.00       1.00      1.00
# uber_low               0.74          -0.08       1.00       1.00      1.00
# uber_close             0.74          -0.07       1.00       1.00      1.00
# uber_volume           -0.06           0.20      -0.17      -0.16     -0.18
#
#                uber_close  uber_volume
# apple_open           0.66        -0.04
# apple_high           0.66        -0.04
# apple_low            0.66        -0.05
# apple_close          0.66        -0.05
# apple_volume        -0.35         0.14
# amazon_open          0.80        -0.09
# amazon_high          0.80        -0.09
# amazon_low           0.81        -0.10
# amazon_close         0.80        -0.09
# amazon_volume       -0.46         0.23
# google_open          0.74        -0.05
# google_high          0.74        -0.05
# google_low           0.74        -0.06
# google_close         0.74        -0.06
# google_volume       -0.07         0.20
# uber_open            1.00        -0.17
# uber_high            1.00        -0.16
# uber_low             1.00        -0.18
# uber_close           1.00        -0.17
# uber_volume         -0.17         1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes = [col for col in df.columns if col.endswith('close')]

# %%
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.56          0.87        0.66
# amazon_close         0.56          1.00          0.76        0.80
# google_close         0.87          0.76          1.00        0.74
# uber_close           0.66          0.80          0.74        1.00

# %%
closes = [col for col in df.columns if col.endswith('close') or col. endswith('volume')]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %% [markdown]
# metoda append()

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-08-08      92.95      94.31     88.91       89.56     26212493
# 2025-08-07      90.72      92.74     89.16       92.67     28522247
# 2025-08-06      90.95      90.96     86.30       89.22     40169819
# 2025-08-05      89.59      90.95     89.05       89.39     25855952
# 2025-08-04      87.62      88.59     87.41       88.43     15138877

# %%
uber_6 = uber[uber.index.month == 6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-06-30      91.69      93.39     91.52       93.30     16155270
# 2025-06-27      91.86      92.51     89.97       91.53     24731168
# 2025-06-26      91.30      94.38     90.88       93.12     23657765
# 2025-06-25      91.56      92.89     90.60       90.90     17400840
# 2025-06-24      87.99      92.48     87.91       91.65     38925080
# ...               ...        ...       ...         ...          ...
# 2021-06-07      50.49      51.22     49.75       50.76     16466233
# 2021-06-04      49.56      50.22     49.07       50.18     10409827
# 2021-06-03      50.43      50.50     48.53       48.70     14712859
# 2021-06-02      51.19      51.41     50.55       50.79     13484205
# 2021-06-01      51.62      51.66     49.84       50.98     16583752
#
# [103 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month == 7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-07-31      87.53      88.84     86.61       87.75     16922440
# 2025-07-30      87.45      87.81     86.47       87.64     16862770
# 2025-07-29      88.89      89.16     86.36       87.11     24966230
# 2025-07-28      91.33      92.35     90.24       90.60     11606054
# 2025-07-25      90.50      91.38     89.50       91.29     13864112
# ...               ...        ...       ...         ...          ...
# 2021-07-08      47.16      48.21     46.57       47.55     24930159
# 2021-07-07      50.80      51.03     48.54       48.68     24559506
# 2021-07-06      50.60      52.03     50.40       50.80     21357834
# 2021-07-02      50.57      51.83     50.39       51.71     13698243
# 2021-07-01      50.88      51.60     50.02       50.59     17732585
#
# [105 rows x 5 columns]

# %%
pd.concat(objs = [uber_6, uber_7])
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2025-06-30      91.69      93.39     91.52       93.30     16155270
# 2025-06-27      91.86      92.51     89.97       91.53     24731168
# 2025-06-26      91.30      94.38     90.88       93.12     23657765
# 2025-06-25      91.56      92.89     90.60       90.90     17400840
# 2025-06-24      87.99      92.48     87.91       91.65     38925080
# ...               ...        ...       ...         ...          ...
# 2021-07-08      47.16      48.21     46.57       47.55     24930159
# 2021-07-07      50.80      51.03     48.54       48.68     24559506
# 2021-07-06      50.60      52.03     50.40       50.80     21357834
# 2021-07-02      50.57      51.83     50.39       51.71     13698243
# 2021-07-01      50.88      51.60     50.02       50.59     17732585
#
# [208 rows x 5 columns]
